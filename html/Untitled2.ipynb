# %%
Distribute[{B, #}, List] & /@ A

# %%
 t1 = {{1, 2}, {3, 4}};
 t2 = {{a, b, c}, {e, f}};

# %%
Distribute[{t2, #}, List] & /@ t1
# Out:
# {{{{a, b, c}, 1}, {{a, b, c}, 2}, {{e, f}, 1}, {{e, f}, 2}},
#
# >   {{{a, b, c}, 3}, {{a, b, c}, 4}, {{e, f}, 3}, {{e, f}, 4}}}

# %%
Distribute[{##,#2}, List]&@@Flatten[{t1,t2},{{2}}]
# Out:
# {{{1, 2}, {3, 4}, {3, 4}}, {{1, 2}, {3, 4}, {e, f}}, {{1, 2}, {e, f}, {3, 4}},
#
# >   {{1, 2}, {e, f}, {e, f}}, {{a, b, c}, {3, 4}, {3, 4}}, {{a, b, c}, {3, 4}, {e, f}},
#
# >   {{a, b, c}, {e, f}, {3, 4}}, {{a, b, c}, {e, f}, {e, f}}}

# %%
want=Flatten[MapThread[Flatten /@ Tuples[{{#1}, #2}] &, {t1, t2}], 1]
# Out:
# {{1, 2, a}, {1, 2, b}, {1, 2, c}, {3, 4, e}, {3, 4, f}}
